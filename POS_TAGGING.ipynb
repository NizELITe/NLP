# %%
# !pip install spacy

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("I will google about natural language processing")

# %%
doc.text
# Out:
# 'I will google about natural language processing'

# %%
doc[-1]
# Out:
# processing

# %%
doc[2].pos_
# Out:
# 'VERB'

# %%
doc[0].tag_
# Out:
# 'PRP'

# %%
spacy.explain('PRP')
# Out:
# 'pronoun, personal'

# %%
for word in doc:
    print(word.text,"------>", word.pos_,word.tag_,spacy.explain(word.tag_))
# Out:
# I ------> PRON PRP pronoun, personal
# will ------> AUX MD verb, modal auxiliary
# google ------> VERB VB verb, base form
# about ------> ADP IN conjunction, subordinating or preposition
# natural ------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# language ------> NOUN NN noun, singular or mass
# processing ------> NOUN NN noun, singular or mass

# %%
doc2 = nlp(u"I read books on Artifical Intelligence")
for word in doc2:
    print(word.text,"------>", word.pos_,word.tag_,spacy.explain(word.tag_))
# Out:
# I ------> PRON PRP pronoun, personal
# read ------> VERB VBP verb, non-3rd person singular present
# books ------> NOUN NNS noun, plural
# on ------> ADP IN conjunction, subordinating or preposition
# Artifical ------> PROPN NNP noun, proper singular
# Intelligence ------> PROPN NNP noun, proper singular

# %%
from spacy import displacy

# %%
displacy.render(doc2,style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dc2ef257d2444277bd148a3413bda897-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">read</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
options={
    'distance':80,
    'compact':True,
    'color':'#fff',
    'bg':'#00a65a'
}

# %%
displacy.render(doc,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f0af641d0c514da5832112db65c28065-0" class="displacy" width="610" height="217.0" direction="ltr" style="max-width: none; height: 217.0px; color: #fff; background: #00a65a; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
# ...

# %%
doc_ner = nlp('/content/ner_dataset.csv')

# %%
doc_ner.text
# Out:
# '/content/ner_dataset.csv'

# %%
df = pd.read_csv('/content/ner_dataset.csv', encoding='ISO-8859-1')
df.head(50)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1           NaN             of   IN      O
# 2           NaN  demonstrators  NNS      O
# 3           NaN           have  VBP      O
# 4           NaN        marched  VBN      O
# 5           NaN        through   IN      O
# 6           NaN         London  NNP  B-geo
# 7           NaN             to   TO      O
# 8           NaN        protest   VB      O
# 9           NaN            the   DT      O
# 10          NaN            war   NN      O
# 11          NaN             in   IN      O
# 12          NaN           Iraq  NNP  B-geo
# 13          NaN            and   CC      O
# 14          NaN         demand   VB      O
# 15          NaN            the   DT      O
# 16          NaN     withdrawal   NN      O
# 17          NaN             of   IN      O
# 18          NaN        British   JJ  B-gpe
# 19          NaN         troops  NNS      O
# 20          NaN           from   IN      O
# ...

# %%
df['Sentence #'].fillna(method='ffill', inplace=True)

sentences = df.groupby('Sentence #')['Word'].apply(lambda words: ' '.join(words.dropna()))
sentence_list = sentences.tolist()
# Out:
# <ipython-input-26-85735a3ae88d>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentence #'].fillna(method='ffill', inplace=True)
# <ipython-input-26-85735a3ae88d>:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Sentence #'].fillna(method='ffill', inplace=True)

# %%
sentence_mini_list = sentence_list[0:10]

# %%
for idx, sentence in enumerate(sentence_mini_list, 1):
    sen = nlp(sentence)
    print(f"\nSENTENCE {idx}:")
    print("=" * 40)
    for word in sen:
        print(word.text,"------>", word.pos_,word.tag_,spacy.explain(word.tag_))
# Out:
# SENTENCE 1:
# ...
# Thousands ------> NOUN NNS noun, plural
# of ------> ADP IN conjunction, subordinating or preposition
# demonstrators ------> NOUN NNS noun, plural
# have ------> AUX VBP verb, non-3rd person singular present
# marched ------> VERB VBN verb, past participle
# through ------> ADP IN conjunction, subordinating or preposition
# London ------> PROPN NNP noun, proper singular
# to ------> PART TO infinitival "to"
# protest ------> VERB VB verb, base form
# the ------> DET DT determiner
# war ------> NOUN NN noun, singular or mass
# in ------> ADP IN conjunction, subordinating or preposition
# Iraq ------> PROPN NNP noun, proper singular
# and ------> CCONJ CC conjunction, coordinating
# demand ------> VERB VB verb, base form
# the ------> DET DT determiner
# withdrawal ------> NOUN NN noun, singular or mass
# of ------> ADP IN conjunction, subordinating or preposition
# British ------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# ...

# %%
options={
    'distance':80,
    'compact':True,
    'color':'#fff',
    'bg':'#00a65a'
}

# %%
for idx, sentence in enumerate(sentence_mini_list, 1):
    sen = nlp(sentence)
    print(f"\nSENTENCE {idx}:")
    print("=" * 40)
    displacy.render(sen,style='dep',jupyter=True,options=options)
# Out:
# SENTENCE 1:
# ...
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3b83574c76324658b86784e24078e1fd-0" class="displacy" width="1890" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: #fff; background: #00a65a; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Thousands</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
# ...
