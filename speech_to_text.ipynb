# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="MBZUAI/artst-v2-asr")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.12k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/619M [00:00<?, ?B/s]
# SpeechT5ForSpeechToText has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
# ...

# %%
# !pip install pydub
# !apt-get install ffmpeg
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
from pydub import AudioSegment

# Path to your .m4a file
input_file = "/content/qari_niz_voice.m4a"

# Load the .m4a file
audio = AudioSegment.from_file(input_file, format="m4a")

# Export the audio to .wav format
output_file = "/content/qari_niz_voice.wav"
audio.export(output_file, format="wav")

print(f"Conversion complete! File saved at {output_file}")
# Out:
# Conversion complete! File saved at /content/qari_niz_voice.wav

# %%
# Path to your audio file
audio_path = "/content/ahmed_audio.wav"

# Perform speech-to-text
transcription = pipe(audio_path)

# Print the transcription result
print("Transcription:", transcription["text"])
# Out:
# Transcription: من مئاتين كالقوس المسلحة

# %%
pip install transformers datasets torchaudio huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(processor=processor, return_tensors="pt")

# %%
from transformers import AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained("MBZUAI/artst-v2-asr")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-590891ff14fd> in <cell line: 3>()
#       1 from transformers import AutoModelForSeq2SeqLM
#       2
# ----> 3 model = AutoModelForSeq2SeqLM.from_pretrained("MBZUAI/artst-v2-asr")
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
# --> 567         raise ValueError(
#     568             f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569             f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#
# ...

# %%
# Load model directly
from transformers import AutoProcessor, AutoModelForSpeechSeq2Seq

processor = AutoProcessor.from_pretrained("MBZUAI/artst-v2-asr")
model = AutoModelForSpeechSeq2Seq.from_pretrained("MBZUAI/artst-v2-asr")

# %%
from datasets import load_dataset, Audio

# Load your dataset
dataset = load_dataset('csv', data_files='your_dataset.csv')

# Map the audio files to the dataset
dataset = dataset.cast_column("audio_filepath", Audio(sampling_rate=16000))

# %%
# Install ffmpeg if it's not already installed
#!apt-get update
#!apt-get install ffmpeg

# Convert AAC to WAV
input_audio_path = "/content/20241206_191431.aac"
output_audio_path = "/content/ahmed_audio4.wav"

# Use FFmpeg to convert the file
# !ffmpeg -i {input_audio_path} {output_audio_path}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# **MMS**

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe2 = pipeline("automatic-speech-recognition", model="facebook/mms-1b-all")
# Out:
# config.json:   0%|          | 0.00/2.04k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/254 [00:00<?, ?B/s]

# %%
# Path to your audio file
audio_path = "/content/ahmed_audio4.wav"

# Perform speech-to-text
transcription = pipe2(audio_path)

# Print the transcription result
print("Transcription:", transcription["text"])
# Out:
# Transcription: fassal lilli rabbi ca vonher
